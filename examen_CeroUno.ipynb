# %%
#Importar las librerías
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Importar la base de datos de mortalidad, para su posterior análisis

mortalidad=pd.read_csv("mortalidad.csv")

# %% [markdown]
# # Análisis inicial

# %%
# para desplegar los encabezados de un DataSet, también a través del list (solamente los nombres de los encabezados)
mortalidad.head()
# Out:
#    Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0               1972                  6                             JUNIO
# 1               1967                  2                           FEBRERO
# 2               1973                  6                             JUNIO
# 3               1966                  1                             ENERO
# 4               1975                  0                   NO ESPECIFICADO
#
#    Día de nacimiento  Genero Clave de la edad  Edad cumplida  Estado conyugal  \
# 0                 25       2                A             29                5
# 1                  1       2                A             35                5
# 2                 21       2                A             29                5
# 3                 23       2                A             36                5
# 4                  0       2                A             30                5
#
# ...

# %%
#para mostrar un dataframe que contenga las columnas que me solicitan, elimino las que NO me piden.
#Muestra un DataFrame que contenga: Edad cumplida, Descripción del estado conyugal, Tamaño de localidad, Localidad de ocurrencia, Descrición de la localidad de ocurrencia
list(mortalidad)
# Out:
# ['Año de nacimiento',
#  'Mes de nacimiento',
#  'Descripción del mes de nacimiento',
#  'Día de nacimiento',
#  'Genero',
#  'Clave de la edad',
#  'Edad cumplida',
#  'Estado conyugal',
#  'Descripción del estado conyugal',
#  'Entidad de residencia',
#  'Descripción de entidad de residencia',
#  'Municipio de residencia',
#  'Descripción del municipio de residencia',
#  'Localidad de residencia',
#  'Descripión de la localidad de residencia',
#  'Tamaño de localidad',
#  'Descripción del tamaño de localidad',
#  'Ocupación habitual',
#  'Descripción de la ocupación habitual',
#  'Escolaridad',
#  'Descripción de la escolaridad',
#  'Derechiahabiencia',
#  'Descrición de la derechiahabiencia',
#  'Entidad de ocurrencia',
#  'Descripción de la entidad de ocurrencia',
#  'Municipio de ocurrencia',
#  'Descrición del municipio de ocurrencia',
#  'Localidad de ocurrencia',
#  'Descrición de la localidad de ocurrencia',
#  'Sitio donde ocurrio la defunción',
# ...

# %%
mortalidad_columnas_borradas = mortalidad.drop(["Año de nacimiento","Mes de nacimiento","Descripción del mes de nacimiento","Día de nacimiento",'Genero',"Clave de la edad","Estado conyugal","Entidad de residencia","Descripción de entidad de residencia","Municipio de residencia","Descripción del municipio de residencia","Localidad de residencia","Descripión de la localidad de residencia","Descripción del tamaño de localidad",'Ocupación habitual', 'Descripción de la ocupación habitual','Escolaridad','Descripción de la escolaridad','Derechiahabiencia','Descrición de la derechiahabiencia', 'Entidad de ocurrencia','Descripción de la entidad de ocurrencia','Municipio de ocurrencia','Descrición del municipio de ocurrencia','Sitio donde ocurrio la defunción', 'Descripción del sitio donde ocurrio la defunción','Año de la defunción','Mes de la defunción','Descrición del mes de la defunción', 'Día de la defunción','Hora de la defunción','Minutos de la defunción', 'Asistencia médica', 'Descripción de la asistencia médica',
 'Causa CIE a  cuarto dígito', 'Descrición de la causa CIE', 'Quien certificó', 'Descrición de quien certificó', 'Entidad de registro', 'Descrición de la entidad de registro', 'Municipio de registro', 'Descrición del municipio de registro', 'Año de registro',
 'Mes de registro', 'Descripción del mes de registro', 'Día de registro', 'Año de la certificación', 'Mes de la certificación', 'Descripció del mes de la certificación', 'Día de la certificación', 'Año de la base de datos', 'Razón de mortalidad materna','Descrición de la razón de mortalidad materna'
],axis=1)

# %%
mortalidad_columnas_borradas.head()
# Out:
#    Edad cumplida Descripción del estado conyugal  Tamaño de localidad  \
# 0             29                          CASADO                    9
# 1             35                          CASADO                    9
# 2             29                          CASADO                    4
# 3             36                          CASADO                    1
# 4             30                          CASADO                    0
#
#    Localidad de ocurrencia Descrición de la localidad de ocurrencia
# 0                        1                     311020001 Valladolid
# 1                        1                         310500001 Mérida
# 2                        1                      310560001 Oxkutzcab
# 3                        1                         310500001 Mérida
# 4                        0                090160000 No especificado

# %% [markdown]
# # Cuántas edades diferentes tenían las madres cuando fallecieron? Obten los estadísticos para esta columna y los valores de las edades diferentes.

# %%
print("Las edades de las mujeres al morir son:")
edades_muerte=mortalidad["Edad cumplida"].unique()
pd.DataFrame(edades_muerte)
# Out:
# Las edades de las mujeres al morir son:
#       0
# 0    29
# 1    35
# 2    36
# 3    30
# 4    20
# 5    27
# 6    43
# 7    31
# 8    39
# 9    45
# 10   42
# 11   17
# 12   38
# 13   26
# 14   21
# 15   22
# 16   40
# 17   44
# 18   34
# 19   41
# 20   33
# 21   13
# 22   24
# 23   25
# 24   37
# 25   19
# 26   23
# 27   32
# 28   28
# 29  998
# 30   15
# 31   46
# 32   48
# 33   16
# 34   18
# 35   12
# 36   47
# 37   14
# 38   51
# 39   50
# 40   54
# 41   49
# 42   11
# 43   53
# 44   81
# 45   70
# 46   82
# 47   59
# 48   86
# 49   65

# %%
#Para saber las estadísticas básicas del dataset
mortalidad.describe()
# Out:
#        Año de nacimiento  Mes de nacimiento  Día de nacimiento   Genero  \
# count       17232.000000       17232.000000       17232.000000  17232.0
# mean         1971.559424           3.758008           9.903726      2.0
# std           128.025187           3.756571          10.157461      0.0
# min             0.000000           0.000000           0.000000      2.0
# 25%          1974.000000           0.000000           0.000000      2.0
# 50%          1980.000000           3.000000           7.000000      2.0
# 75%          1986.000000           7.000000          19.000000      2.0
# max          2002.000000          12.000000          31.000000      2.0
#
#        Edad cumplida  Estado conyugal  Entidad de residencia  \
# count   17232.000000     17232.000000           17232.000000
# mean       29.765727         3.918001              16.293350
# std        36.916010         1.454535               7.844138
# min        11.000000         0.000000               0.000000
# ...

# %% [markdown]
# ## Imprime los valores de los años de defunción ¿ Existen datos que son lógicos, es decir, están correctos?

# %%
print("Año de registro:")
año_defuncion=mortalidad["Año de registro"].unique()
pd.DataFrame(año_defuncion)
# Out:
# Año de registro:
#        0
# 0   2002
# 1   2005
# 2   2003
# 3   2008
# 4   2013
# 5   2012
# 6   2009
# 7   2010
# 8   2011
# 9   2004
# 10  2006
# 11  2007
# 12  2014
# 13  2015
# 14  2016

# %% [markdown]
# ##  Cuántos tipos de escolaridad existen?

# %%
print("Tipos de escolaridad:")
tipos_escolaridad=mortalidad["Descripción de la escolaridad"].unique()
pd.DataFrame(tipos_escolaridad)
# Out:
# Tipos de escolaridad:
#                                          0
# 0                      PRIMARIA INCOMPLETA
# 1                    SECUNDARIA INCOMPLETA
# 2                              PROFESIONAL
# 3                                  NINGUNA
# 4                      SECUNDARIA COMPLETA
# 5                          NO ESPECIFICADO
# 6                                 POSGRADO
# 7                        PRIMARIA COMPLETA
# 8     BACHILLERATO O PREPARATORIA COMPLETA
# 9   BACHILLERATO O PREPARATORIA INCOMPLETA
# 10                     NO ESPECIFICADO\r\n
# 11                              PREESCOLAR

# %% [markdown]
# # Qué entidad tiene el mayor número de muertes

# %%
entidad= mortalidad['Descripción de entidad de residencia']
entidad.value_counts()
# Out:
# México                             2481
# Veracruz de Ignacio de la Llave    1273
# Chiapas                            1232
# Distrito Federal                   1148
# Puebla                             1042
# Guerrero                            977
# Oaxaca                              879
# Jalisco                             822
# Guanajuato                          702
# Michoacán de Ocampo                 671
# Chihuahua                           657
# Hidalgo                             439
# San Luis Potosí                     382
# Tamaulipas                          373
# Baja California                     362
# Nuevo León                          332
# Tabasco                             323
# Coahuila de Zaragoza                318
# Sonora                              313
# Sinaloa                             288
# Durango                             279
# Yucatán                             267
# Morelos                             252
# ...

# %%
el_mayor=max(entidad.value_counts())
print("La entidad con mayor número de muertes es México, con : " , el_mayor, "muertes.")
# Out:
# La entidad con mayor número de muertes es México, con :  2481 muertes.

# %%
mortalidad1=mortalidad.set_index("Descrición de la razón de mortalidad materna")
mortalidad1_pocas = mortalidad1.drop(["Año de nacimiento","Mes de nacimiento","Descripción del mes de nacimiento","Día de nacimiento",'Genero',"Clave de la edad","Estado conyugal","Entidad de residencia","Descripción de entidad de residencia","Municipio de residencia","Descripción del municipio de residencia","Localidad de residencia","Descripión de la localidad de residencia","Descripción del tamaño de localidad",'Ocupación habitual', 'Descripción de la ocupación habitual','Escolaridad','Descripción de la escolaridad','Derechiahabiencia','Descrición de la derechiahabiencia', 'Entidad de ocurrencia','Descripción de la entidad de ocurrencia','Municipio de ocurrencia','Descrición del municipio de ocurrencia','Sitio donde ocurrio la defunción', 'Descripción del sitio donde ocurrio la defunción','Año de la defunción','Mes de la defunción','Descrición del mes de la defunción', 'Día de la defunción','Hora de la defunción','Minutos de la defunción', 'Asistencia médica', 'Descripción de la asistencia médica',
 'Causa CIE a  cuarto dígito', 'Descrición de la causa CIE', 'Quien certificó', 'Descrición de quien certificó', 'Entidad de registro', 'Descrición de la entidad de registro', 'Municipio de registro', 'Descrición del municipio de registro', 'Año de registro',
 'Mes de registro', 'Descripción del mes de registro', 'Día de registro', 'Año de la certificación', 'Mes de la certificación', 'Descripció del mes de la certificación', 'Día de la certificación', 'Año de la base de datos', 'Razón de mortalidad materna',
],axis=1)
#mortalidad2= mortalidad1.loc["MEX"]
pd.DataFrame(mortalidad1_pocas)
# Out:
#                                                     Edad cumplida  \
# Descrición de la razón de mortalidad materna
# Muertes Maternas para la razón de Mortalidad Ma...             29
# Muertes Maternas para la razón de Mortalidad Ma...             35
# Muertes Maternas para la razón de Mortalidad Ma...             29
# Muertes Maternas para la razón de Mortalidad Ma...             36
# Muertes Maternas para la razón de Mortalidad Ma...             30
# Muertes Maternas para la razón de Mortalidad Ma...             30
# Muertes Maternas para la razón de Mortalidad Ma...             20
# Muertes Maternas para la razón de Mortalidad Ma...             27
# Muertes Maternas para la razón de Mortalidad Ma...             43
# Muertes Maternas para la razón de Mortalidad Ma...             31
# Muertes Maternas para la razón de Mortalidad Ma...             31
# Muertes Maternas para la razón de Mortalidad Ma...             35
# ...

# %%
#Ya que me soliditan solamente el encabezado, ejecuto el comando head
pd.DataFrame(mortalidad1_pocas).head()
# Out:
#                                                     Edad cumplida  \
# Descrición de la razón de mortalidad materna
# Muertes Maternas para la razón de Mortalidad Ma...             29
# Muertes Maternas para la razón de Mortalidad Ma...             35
# Muertes Maternas para la razón de Mortalidad Ma...             29
# Muertes Maternas para la razón de Mortalidad Ma...             36
# Muertes Maternas para la razón de Mortalidad Ma...             30
#
#                                                    Descripción del estado conyugal  \
# Descrición de la razón de mortalidad materna
# Muertes Maternas para la razón de Mortalidad Ma...                          CASADO
# Muertes Maternas para la razón de Mortalidad Ma...                          CASADO
# Muertes Maternas para la razón de Mortalidad Ma...                          CASADO
# Muertes Maternas para la razón de Mortalidad Ma...                          CASADO
# ...

# %% [markdown]
# ### En el DataSet mostrado previamente, intenté descifrar las causas principales de la mortandad, pero observo que solamente tiene dos valores (0 y 1) y creo que no existe información suficiente para dar un diagnóstico.

# %%
mortalidad2=mortalidad.set_index("Descripción de la escolaridad")
mortalidad2_pocas = mortalidad2.drop(["Año de nacimiento","Mes de nacimiento","Descripción del mes de nacimiento","Día de nacimiento",'Genero',"Clave de la edad","Estado conyugal","Entidad de residencia","Descripción de entidad de residencia","Municipio de residencia","Descripción del municipio de residencia","Localidad de residencia","Descripión de la localidad de residencia","Descripción del tamaño de localidad",'Ocupación habitual', 'Descripción de la ocupación habitual','Escolaridad','Derechiahabiencia','Descrición de la derechiahabiencia', 'Entidad de ocurrencia','Descripción de la entidad de ocurrencia','Municipio de ocurrencia','Descrición del municipio de ocurrencia','Sitio donde ocurrio la defunción', 'Descripción del sitio donde ocurrio la defunción','Año de la defunción','Mes de la defunción','Descrición del mes de la defunción', 'Día de la defunción','Hora de la defunción','Minutos de la defunción', 'Asistencia médica', 'Descripción de la asistencia médica',
 'Causa CIE a  cuarto dígito', 'Descrición de la causa CIE', 'Quien certificó', 'Descrición de quien certificó', 'Entidad de registro', 'Descrición de la entidad de registro', 'Municipio de registro', 'Descrición del municipio de registro', 'Año de registro',
 'Mes de registro', 'Descripción del mes de registro', 'Día de registro', 'Año de la certificación', 'Mes de la certificación', 'Descripció del mes de la certificación', 'Día de la certificación', 'Año de la base de datos', 'Razón de mortalidad materna',
],axis=1)
pd.DataFrame(mortalidad2_pocas).head()
# Out:
#                                Edad cumplida Descripción del estado conyugal  \
# Descripción de la escolaridad
# PRIMARIA INCOMPLETA                       29                          CASADO
# PRIMARIA INCOMPLETA                       35                          CASADO
# PRIMARIA INCOMPLETA                       29                          CASADO
# PRIMARIA INCOMPLETA                       36                          CASADO
# SECUNDARIA INCOMPLETA                     30                          CASADO
#
#                                Tamaño de localidad  Localidad de ocurrencia  \
# Descripción de la escolaridad
# PRIMARIA INCOMPLETA                              9                        1
# PRIMARIA INCOMPLETA                              9                        1
# PRIMARIA INCOMPLETA                              4                        1
# PRIMARIA INCOMPLETA                              1                        1
# ...

# %% [markdown]
# ###  En el segundo DataSet, pretendo encontrar una correlación entre la escolaridad y la muerte de las mujeres.

# %% [markdown]
# # Parte 5 - Información gráfica

# %% [markdown]
# ###  Gráfica de línea

# %%
DatosEscolaridad = mortalidad['Descripción de la escolaridad']

# %%
mortalidad['Edad cumplida'].plot(kind='line')
plt.xlabel('Entidades')
plt.ylabel('Mortalidad')
plt.title('Mortalidad por entidades')
plt.show()

# %% [markdown]
# ####  OBSERVACIÓN: Creo que la gráfica (el comando) funcionó, pero está mal planteada.
